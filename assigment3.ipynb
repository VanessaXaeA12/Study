# %%
#⌴Header 1

# %%
#Libraries used

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import files 

name = "mcdonalds_menu.csv"

# import menu and display the first two rows of the dataframe
df = pd.read_csv(name)
df.reset_index(inplace=True) #resetting the index (otherwise category is the new index and it messes up with merge)

# %%
#The code 

#1. make new data frame with only those columns
df = df.loc[0:len(df),['Calories', 'Total Fat', 'Saturated Fat', 'Cholesterol', 'Sodium', 'Carbohydrates', 'Sugars', 'Protein']]

#2. plot data frame
pd.plotting.scatter_matrix(df, diagonal='kde', figsize=(20,12), grid=True)
# Out:
# array([[<AxesSubplot:xlabel='Calories', ylabel='Calories'>,
#         <AxesSubplot:xlabel='Total Fat', ylabel='Calories'>,
#         <AxesSubplot:xlabel='Saturated Fat', ylabel='Calories'>,
#         <AxesSubplot:xlabel='Cholesterol', ylabel='Calories'>,
#         <AxesSubplot:xlabel='Sodium', ylabel='Calories'>,
#         <AxesSubplot:xlabel='Carbohydrates', ylabel='Calories'>,
#         <AxesSubplot:xlabel='Sugars', ylabel='Calories'>,
#         <AxesSubplot:xlabel='Protein', ylabel='Calories'>],
#        [<AxesSubplot:xlabel='Calories', ylabel='Total Fat'>,
#         <AxesSubplot:xlabel='Total Fat', ylabel='Total Fat'>,
#         <AxesSubplot:xlabel='Saturated Fat', ylabel='Total Fat'>,
#         <AxesSubplot:xlabel='Cholesterol', ylabel='Total Fat'>,
#         <AxesSubplot:xlabel='Sodium', ylabel='Total Fat'>,
#         <AxesSubplot:xlabel='Carbohydrates', ylabel='Total Fat'>,
#         <AxesSubplot:xlabel='Sugars', ylabel='Total Fat'>,
# ...
